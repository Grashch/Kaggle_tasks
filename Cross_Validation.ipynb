# %% [markdown]
# <a href="https://colab.research.google.com/github/Grashch/Kaggle_tasks/blob/main/Cross_Validation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('/content/melb_data.csv')
X = data[['Rooms', 'Distance', 'Landsize', 'BuildingArea', 'YearBuilt']]
y = data.Price

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor

# %%
pipeline = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='mean')),
    ('modeling', RandomForestRegressor(
        n_estimators=50,
        random_state=24))
])

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(
    pipeline, X, y,
    cv = 5,
    scoring = 'neg_mean_absolute_percentage_error'
)

print(f'MAE:\n{-1*score}')
# Out:
# MAE:
# [0.26139911 0.31934298 0.28904374 0.23491782 0.24561803]

# %%
print(f'Mean absolute percentage error:\n{-100*score.mean():.2f}')
# Out:
# Mean absolute percentage error:
# 27.01
